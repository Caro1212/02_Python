# %%
import pandas as pd


my_vp = pd.read_csv("C:/Users/Caroline Kries/sciebo/Forschungsprojekt Medikamenteninteraktion/03_Daten/my_vp")
my_medi = pd.read_csv("C:/Users/Caroline Kries/sciebo/Forschungsprojekt Medikamenteninteraktion/03_Daten/my_medi")
my_inhalt = pd.read_csv("C:/Users/Caroline Kries/sciebo/Forschungsprojekt Medikamenteninteraktion/03_Daten/my_inhalt")
# Out:
# C:\Users\Caroline Kries\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
my_vp
# Out:
#         Unnamed: 0       id  klientid                datum bezeichnung  \
# 0              953      954      4197  2011-04-26 07:45:00  Blutzucker
# 1              954      955      4197  2011-04-26 11:15:00  Blutzucker
# 2              955      956      4197  2011-04-26 17:15:00  Blutzucker
# 3              956      957      4197  2011-04-27 07:45:00  Blutzucker
# 4              957      958      4197  2011-04-27 11:15:00  Blutzucker
# ...            ...      ...       ...                  ...         ...
# 155649     1072097  1072098      7957  2014-10-23 18:00:00  Blutzucker
# 155650     1072098  1072099      7957  2014-10-23 23:44:00  Blutzucker
# 155651     1072099  1072100      7957  2014-10-24 08:05:00  Blutzucker
# 155652     1072100  1072101      7957  2014-10-24 11:30:00   Blutdruck
# 155653     1072101  1072102      7957  2014-10-24 11:40:00  Blutzucker
#
#           wert einheit  wurdeunterschritten  wurdeueberschritten  werte  \
# ...

# %%
klienten = list(my_vp.klientid.unique())

# %%
single_klient = my_vp[my_vp["klientid"] == klienten[11]]
blut_single_klient = single_klient[single_klient["bezeichnung"] == "Blutdruck"]
blut_single_klient
# Out:
#        Unnamed: 0      id  klientid                datum bezeichnung    wert  \
# 12605      133976  133977      8711  2011-08-28 14:30:00   Blutdruck  130/80
# 12687      134059  134060      8711  2011-09-22 08:56:00   Blutdruck  140/80
# 12946      135517  135518      8711  2011-10-17 08:34:00   Blutdruck  130/70
# 13184      136770  136771      8711  2011-11-29 08:41:00   Blutdruck  130/80
# 13481      139690  139691      8711  2011-12-12 07:41:00   Blutdruck  120/70
# ...           ...     ...       ...                  ...         ...     ...
# 27692      256827  256828      8711  2018-11-23 08:37:00   Blutdruck  120/70
# 27727      256863  256864      8711  2018-12-03 10:30:00   Blutdruck  110/60
# 27771      258153  258154      8711  2018-12-11 06:30:00   Blutdruck  100/80
# 27863      258245  258246      8711  2019-01-10 14:21:00   Blutdruck  120/70
# 27916      258955  258956      8711  2019-01-17 08:05:00   Blutdruck  120/80
#
# ...

# %%
import numpy as np

werte = list(blut_single_klient.wert.apply(str))
neu = [float(x.split("/")[0]) if len(x)>1 else np.NaN for x in werte]
blut_single_klient["wert"] = neu
# Out:
# <ipython-input-16-166d4807e09c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blut_single_klient["wert"] = neu

# %%
blut_single_klient
# Out:
#        Unnamed: 0      id  klientid                datum bezeichnung   wert  \
# 12605      133976  133977      8711  2011-08-28 14:30:00   Blutdruck  130.0
# 12687      134059  134060      8711  2011-09-22 08:56:00   Blutdruck  140.0
# 12946      135517  135518      8711  2011-10-17 08:34:00   Blutdruck  130.0
# 13184      136770  136771      8711  2011-11-29 08:41:00   Blutdruck  130.0
# 13481      139690  139691      8711  2011-12-12 07:41:00   Blutdruck  120.0
# ...           ...     ...       ...                  ...         ...    ...
# 27692      256827  256828      8711  2018-11-23 08:37:00   Blutdruck  120.0
# 27727      256863  256864      8711  2018-12-03 10:30:00   Blutdruck  110.0
# 27771      258153  258154      8711  2018-12-11 06:30:00   Blutdruck  100.0
# 27863      258245  258246      8711  2019-01-10 14:21:00   Blutdruck  120.0
# 27916      258955  258956      8711  2019-01-17 08:05:00   Blutdruck  120.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
blut_single_klient["datum"] = pd.to_datetime(blut_single_klient.datum)
# Out:
# <ipython-input-19-92da20c06e3a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blut_single_klient["datum"] = pd.to_datetime(blut_single_klient.datum)

# %%
plt.plot(blut_single_klient.datum, blut_single_klient.wert)

# %%
single_klient_medi = my_medi[my_medi["klientid"] == klienten[11]]

# %%
from Python.TimelineDiagnosesDrugs import plot_drugs
from Python.TimelineDiagnosesDrugs import plot_diagnoses

plot_drugs(klienten[11])
plot_diagnoses(klienten[11])
# Out:
# C:\Users\Caroline Kries\sciebo\Forschungsprojekt Medikamenteninteraktion\Python\TimelineDiagnosesDrugs.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how="any", inplace=True)
